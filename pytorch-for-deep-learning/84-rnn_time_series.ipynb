# %%
import torch
import torch.nn as nn

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# plotting datetime values 
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('../pytorch-for-deep-learning/Data/Alcohol_Sales.csv', index_col=0, parse_dates=True)
df.tail()
# Out:
#             S4248SM144NCEN
# DATE
# 2018-09-01           12396
# 2018-10-01           13914
# 2018-11-01           14174
# 2018-12-01           15504
# 2019-01-01           10718

# %%
len(df)
# Out:
# 325

# %%
df.plot(figsize=(12,4))
# Out:
# <Axes: xlabel='DATE'>
