# %%
# !pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 84.0 MB/s eta 0:00:00
# ...

# %%
from PIL import Image

# %%
pic = Image.open("puppy.png")

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x1024>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
import numpy as np
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (1024, 1024, 4)

# %%
import matplotlib.pyplot as plt
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
pic_red[:,:,1] = 0 # remove green channel

# %%
plt.imshow(pic_red)
